# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
features_df = pd.read_csv('data/kc_house_data.csv', index_col='id')
features_df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
features_df_clean = features_df.drop(['waterfront', 
                                      'view', 
                                      'condition', 
                                      'grade', 
                                      'zipcode', 
                                      'sqft_basement', 
                                      'date'], 
                                     axis=1)
x = features_df_clean.drop('price', axis=1)
y = features_df_clean.price

# %%
features_df.groupby('zipcode').count()['date']
# Out:
# zipcode
# 98001    361
# 98002    199
# 98003    280
# 98004    317
# 98005    168
#         ...
# 98177    255
# 98178    262
# 98188    136
# 98198    280
# 98199    317
# Name: date, Length: 70, dtype: int64

# %%
features_dt = pd.to_datetime(features_df['date'])
features_dt = pd.concat([features_dt, features_df.price], axis=1)

plt.scatter(features_dt.date, features_dt.price, s=.1)
